# %%
import pandas as pd
import numpy as np
from time import sleep
from openai import OpenAI
from private_data import API_KEY
import re

# %%
# Main query function
client = OpenAI(api_key=API_KEY)
def ask_query(query):
    my_query = [ {"role": "system", "content": "Give direct answer without any explanation."},
        {"role": "user", "content": query} ] 
    completion = client.chat.completions.create(
        model="gpt-3.5-turbo", messages=my_query
    )
    return str(completion.choices[0].message.content)

# %%
def occupation_analogy_testing(df1, df2, equiv_func):
    result = []
    
    for i in range(len(df1)):
        entity_1 = df1.iloc[i]['Entity']
        target_1 = df1.iloc[i]['Target']

        for j in range(len(df2)):
        
            entity_2 = df2.iloc[j]['Entity']
            target_2 = df2.iloc[j]['Target']
            correct_ans = df2.iloc[j]['Correct']
            
            prompt = f"{entity_1}:({target_1})::{entity_2}:X; what is X?"
           
            response = ask_query(prompt)
            
            status = "Fully Wrong"
            if equiv_func(response, target_2)==1:
                status = "Analogically Correct"
            elif equiv_func(response, correct_ans)==1:
                status = "Technically Correct"
            
            result.append({'Prompt': prompt, 'Analogical Answer': target_2, 'Technical Answer': correct_ans , 'GPT-reply': response, 'Status': status})
            print(f"Prompt: {prompt} \t|\t Analogical Answer: {target_2}, Technical Answer: {correct_ans} \t|\t Response: {response} \t|\t Status: {status}")
    
    return result

# %%
# Loading Dataset 
person_occupation_df = pd.read_csv('../data/pantheon.tsv', sep='\t')
person_occupation_df = person_occupation_df[['name', 'countryName', 'occupation']]
# Shuffle and resize the data
person_occupation_df = person_occupation_df.sample(frac=1).reset_index(drop=True).head(100)

person_occupation_df
# Out:
#                   name     countryName        occupation
# 0            Paul Berg   UNITED STATES           CHEMIST
# 1        Kirsten Dunst   UNITED STATES             ACTOR
# 2        Ali al-Masudi            Iraq            WRITER
# 3       Carlo Borromeo           ITALY  RELIGIOUS FIGURE
# 4         Edvard Grieg          NORWAY          COMPOSER
# ..                 ...             ...               ...
# 95      Deryck Whibley          CANADA            SINGER
# 96                Deco          Brazil     SOCCER PLAYER
# 97         Pope Pius V           ITALY  RELIGIOUS FIGURE
# 98  Chrétien de Troyes          FRANCE            WRITER
# 99         Eric Burdon  UNITED KINGDOM            SINGER
#
# [100 rows x 3 columns]

# %%
# Preprocessing 

def normalize_occupation(occupation):
    occupation = occupation.lower()
    if 'player' in occupation:
        occupation = occupation.replace('player', '')
    if 'actor' in occupation:
        return 'actor'
    if 'actress' in occupation:
        return 'actor'
    if 'artist' in occupation:
        return 'painter'
    
    return occupation
    

def are_equivalent(response, answer):
    response = normalize_occupation(response)
    answer = normalize_occupation(answer)

    if answer in response:
        return 1
    if response in answer:
        return 1
    
    if 'known' in response: # part of responses like: "unknown", "don't know"
        return 0
    
    return 2    # incase of an alternative answer

    

def does_gpt_know(person, occupation):
    query = f"what is the occupation of {person}?"
    response = ask_query(query)
    print(f"Person: {person} \t|\t Occupation: {occupation} \t|\t Response: {response}")
    return are_equivalent(response, occupation)




def preprocess(df):
    correct_answers = []
    wrong_answers = []
    for index, row in df.iterrows():
        x = does_gpt_know(row['name'], row['occupation'])
        if x==1:
            correct_answers.append(row)
        elif x==2:
            wrong_answers.append(row)
        print(len(correct_answers), len(wrong_answers))
        if len(correct_answers) >= 10 and len(wrong_answers)>=10:
            break
    correct_df = pd.DataFrame(correct_answers)
    wrong_df = pd.DataFrame(wrong_answers)
    return correct_df, wrong_df

# %%
known_df = preprocess(person_occupation_df)
known_df
# Out:
# Person: Paul Berg 	|	 Occupation: CHEMIST 	|	 Response: Biochemist.
# 1 0
# Person: Kirsten Dunst 	|	 Occupation: ACTOR 	|	 Response: Actress.
# 2 0
# Person: Ali al-Masudi 	|	 Occupation: WRITER 	|	 Response: Historian.
# 2 1
# Person: Carlo Borromeo 	|	 Occupation: RELIGIOUS FIGURE 	|	 Response: Roman Catholic Cardinal
# 2 2
# Person: Edvard Grieg 	|	 Occupation: COMPOSER 	|	 Response: Composer.
# 3 2
# Person: Gerardus 't Hooft 	|	 Occupation: PHYSICIST 	|	 Response: Physicist.
# 4 2
# Person: Antoninus Pius 	|	 Occupation: POLITICIAN 	|	 Response: Emperor of Rome.
# 4 3
# Person: William IX, Duke of Aquitaine 	|	 Occupation: NOBLEMAN 	|	 Response: Poet and troubadour.
# 4 4
# Person: Pope Martin I 	|	 Occupation: RELIGIOUS FIGURE 	|	 Response: Pope Martin I was a clergyman.
# 4 5
# Person: Kateryna Bondarenko 	|	 Occupation: TENNIS PLAYER 	|	 Response: Professional tennis player.
# 5 5
# Person: Yannis Ritsos 	|	 Occupation: SOCIAL ACTIVIST 	|	 Response: Poet.
# 5 6
# Person: Johannes Andreas Grib Fibiger 	|	 Occupation: PHYSICIAN 	|	 Response: Physiologist.
# 5 7
# Person: John Hurt 	|	 Occupation: ACTOR 	|	 Response: Actor.
# 6 7
# Person: Valdis Zatlers 	|	 Occupation: POLITICIAN 	|	 Response: Valdis Zatlers is a physician.
# 6 8
# Person: Gianfranco Zola 	|	 Occupation: SOCCER PLAYER 	|	 Response: Football manager
# 6 9
# Person: Željko Joksimović 	|	 Occupation: MUSICIAN 	|	 Response: Singer and songwriter.
# 6 10
# Person: Ish-bosheth 	|	 Occupation: POLITICIAN 	|	 Response: King of Israel
# 6 11
# Person: Fernando Verdasco 	|	 Occupation: TENNIS PLAYER 	|	 Response: Tennis player.
# 7 11
# Person: Danny Trejo 	|	 Occupation: ACTOR 	|	 Response: Actor
# 8 11
# Person: Emil Cioran 	|	 Occupation: PHILOSOPHER 	|	 Response: Philosopher.
# 9 11
# Person: Edward VII of the United Kingdom 	|	 Occupation: NOBLEMAN 	|	 Response: King of the United Kingdom
# 9 12
# Person: Daniel Jarque 	|	 Occupation: SOCCER PLAYER 	|	 Response: Professional footballer.
# 9 13
# Person: Georges Brassens 	|	 Occupation: SINGER 	|	 Response: Singer-songwriter.
# 10 13
# (                   name     countryName     occupation
#  0             Paul Berg   UNITED STATES        CHEMIST
#  1         Kirsten Dunst   UNITED STATES          ACTOR
#  4          Edvard Grieg          NORWAY       COMPOSER
#  5     Gerardus 't Hooft     NETHERLANDS      PHYSICIST
#  9   Kateryna Bondarenko         UKRAINE  TENNIS PLAYER
#  12            John Hurt  UNITED KINGDOM          ACTOR
#  17    Fernando Verdasco           SPAIN  TENNIS PLAYER
#  18          Danny Trejo   United States          ACTOR
#  19          Emil Cioran         ROMANIA    PHILOSOPHER
#  22     Georges Brassens          France         SINGER,
#                                  name     countryName        occupation
#  2                      Ali al-Masudi            Iraq            WRITER
#  3                     Carlo Borromeo           ITALY  RELIGIOUS FIGURE
#  6                     Antoninus Pius           ITALY        POLITICIAN
#  7      William IX, Duke of Aquitaine          France          NOBLEMAN
#  8                      Pope Martin I           Italy  RELIGIOUS FIGURE
#  10                     Yannis Ritsos          Greece   SOCIAL ACTIVIST
#  11     Johannes Andreas Grib Fibiger         DENMARK         PHYSICIAN
#  13                    Valdis Zatlers          LATVIA        POLITICIAN
#  14                   Gianfranco Zola           ITALY     SOCCER PLAYER
#  15                 Željko Joksimović          SERBIA          MUSICIAN
#  16                       Ish-bosheth         Unknown        POLITICIAN
#  20  Edward VII of the United Kingdom  United Kingdom          NOBLEMAN
#  21                     Daniel Jarque           SPAIN     SOCCER PLAYER)

# %%
correct_df, b = known_df
correct_df = correct_df.sample(frac=1).reset_index(drop=True).head(20)
correct_df.rename(columns={'name': 'Entity', 'occupation': 'Target'}, inplace=True)
correct_df
# Out:
#                 Entity     countryName         Target
# 0        Kirsten Dunst   UNITED STATES          ACTOR
# 1     Georges Brassens          France         SINGER
# 2          Emil Cioran         ROMANIA    PHILOSOPHER
# 3    Gerardus 't Hooft     NETHERLANDS      PHYSICIST
# 4    Fernando Verdasco           SPAIN  TENNIS PLAYER
# 5         Edvard Grieg          NORWAY       COMPOSER
# 6  Kateryna Bondarenko         UKRAINE  TENNIS PLAYER
# 7            Paul Berg   UNITED STATES        CHEMIST
# 8          Danny Trejo   United States          ACTOR
# 9            John Hurt  UNITED KINGDOM          ACTOR

# %%
# Creating a dataset with all the provided rows, excluding the numbers.

all_data = {
    'name': ['Paul Berg', 'Kirsten Dunst', 'Ali al-Masudi', 'Carlo Borromeo', 'Edvard Grieg', 'Gerardus \'t Hooft', 'Antoninus Pius', 'William IX, Duke of Aquitaine', 'Pope Martin I', 'Kateryna Bondarenko', 'Yannis Ritsos', 'Johannes Andreas Grib Fibiger', 'John Hurt', 'Valdis Zatlers', 'Gianfranco Zola', 'Željko Joksimović', 'Ish-bosheth', 'Fernando Verdasco', 'Danny Trejo', 'Emil Cioran', 'Edward VII of the United Kingdom', 'Daniel Jarque', 'Georges Brassens'],
    'occupation': ['CHEMIST', 'ACTOR', 'WRITER', 'RELIGIOUS FIGURE', 'COMPOSER', 'PHYSICIST', 'POLITICIAN', 'NOBLEMAN', 'RELIGIOUS FIGURE', 'TENNIS PLAYER', 'SOCIAL ACTIVIST', 'PHYSICIAN', 'ACTOR', 'POLITICIAN', 'SOCCER PLAYER', 'MUSICIAN', 'POLITICIAN', 'TENNIS PLAYER', 'ACTOR', 'PHILOSOPHER', 'NOBLEMAN', 'SOCCER PLAYER', 'SINGER'],
    'response': ['Biochemist', 'Actress', 'Historian', 'Roman Catholic Cardinal', 'Composer', 'Physicist', 'Emperor of Rome', 'Poet and troubadour', 'Pope Martin I was a clergyman', 'Professional tennis player', 'Poet', 'Physiologist', 'Actor', 'Valdis Zatlers is a physician', 'Football manager', 'Singer and songwriter', 'King of Israel', 'Tennis player', 'Actor', 'Philosopher', 'King of the United Kingdom', 'Professional footballer', 'Singer-songwriter']
}

# Convert the all_data dictionary into a pandas DataFrame
df_all = pd.DataFrame(all_data)
df_all
# Out:
#                                 name        occupation  \
# 0                          Paul Berg           CHEMIST
# 1                      Kirsten Dunst             ACTOR
# 2                      Ali al-Masudi            WRITER
# 3                     Carlo Borromeo  RELIGIOUS FIGURE
# 4                       Edvard Grieg          COMPOSER
# 5                  Gerardus 't Hooft         PHYSICIST
# 6                     Antoninus Pius        POLITICIAN
# 7      William IX, Duke of Aquitaine          NOBLEMAN
# 8                      Pope Martin I  RELIGIOUS FIGURE
# 9                Kateryna Bondarenko     TENNIS PLAYER
# 10                     Yannis Ritsos   SOCIAL ACTIVIST
# 11     Johannes Andreas Grib Fibiger         PHYSICIAN
# 12                         John Hurt             ACTOR
# 13                    Valdis Zatlers        POLITICIAN
# 14                   Gianfranco Zola     SOCCER PLAYER
# 15                 Željko Joksimović          MUSICIAN
# 16                       Ish-bosheth        POLITICIAN
# 17                 Fernando Verdasco     TENNIS PLAYER
# 18                       Danny Trejo             ACTOR
# 19                       Emil Cioran       PHILOSOPHER
# 20  Edward VII of the United Kingdom          NOBLEMAN
# 21                     Daniel Jarque     SOCCER PLAYER
# 22                  Georges Brassens            SINGER
#
#                          response
# 0                      Biochemist
# 1                         Actress
# 2                       Historian
# 3         Roman Catholic Cardinal
# 4                        Composer
# 5                       Physicist
# 6                 Emperor of Rome
# 7             Poet and troubadour
# 8   Pope Martin I was a clergyman
# 9      Professional tennis player
# 10                           Poet
# 11                   Physiologist
# 12                          Actor
# 13  Valdis Zatlers is a physician
# 14               Football manager
# 15          Singer and songwriter
# 16                 King of Israel
# 17                  Tennis player
# 18                          Actor
# 19                    Philosopher
# 20     King of the United Kingdom
# 21        Professional footballer
# 22              Singer-songwriter

# %%
li = []
for index, row in df_all.iterrows():
    if are_equivalent(row['response'], row['occupation']) == 2:
        li.append(row)

# %%
# Create the updated DataFrame
wrong_df = pd.DataFrame(li)
wrong_df.rename(columns={'name': 'Entity', 'response': 'Target', 'occupation': 'Correct'}, inplace=True)

wrong_df
# Out:
#                               Entity           Correct  \
# 2                      Ali al-Masudi            WRITER
# 3                     Carlo Borromeo  RELIGIOUS FIGURE
# 6                     Antoninus Pius        POLITICIAN
# 7      William IX, Duke of Aquitaine          NOBLEMAN
# 8                      Pope Martin I  RELIGIOUS FIGURE
# 10                     Yannis Ritsos   SOCIAL ACTIVIST
# 11     Johannes Andreas Grib Fibiger         PHYSICIAN
# 13                    Valdis Zatlers        POLITICIAN
# 14                   Gianfranco Zola     SOCCER PLAYER
# 15                 Željko Joksimović          MUSICIAN
# 16                       Ish-bosheth        POLITICIAN
# 20  Edward VII of the United Kingdom          NOBLEMAN
# 21                     Daniel Jarque     SOCCER PLAYER
#
#                            Target
# 2                       Historian
# 3         Roman Catholic Cardinal
# 6                 Emperor of Rome
# 7             Poet and troubadour
# 8   Pope Martin I was a clergyman
# 10                           Poet
# 11                   Physiologist
# 13  Valdis Zatlers is a physician
# 14               Football manager
# 15          Singer and songwriter
# 16                 King of Israel
# 20     King of the United Kingdom
# 21        Professional footballer

# %%
result = occupation_analogy_testing(correct_df, wrong_df, are_equivalent)

# %%
# result_df = pd.DataFrame(columns=['Prompt', 'Analogical Answer', 'Technical Answer', 'Response', 'Status'], data=result)
result_df.to_csv('../results/result: person-occupation-adversial.csv')
result_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # result_df = pd.DataFrame(columns=['Prompt', 'Analogical Answer', 'Technical Answer', 'Response', 'Status'], data=result)
# ----> 2 result_df.to_csv('../results/result: person-occupation-adversial.csv')
#       3 result_df
#
# NameError: name 'result_df' is not defined

# %%
# Creating a pandas DataFrame with the given prompts and their evaluations (Part 1)
data_part1 = {
    "Prompt": [
        "Kirsten Dunst:(ACTOR)::Ali al-Masudi:X",
        "Kirsten Dunst:(ACTOR)::Carlo Borromeo:X",
        "Kirsten Dunst:(ACTOR)::Antoninus Pius:X",
        "Kirsten Dunst:(ACTOR)::William IX, Duke of Aquitaine:X",
        "Kirsten Dunst:(ACTOR)::Pope Martin I:X",
        "Kirsten Dunst:(ACTOR)::Yannis Ritsos:X",
        "Kirsten Dunst:(ACTOR)::Johannes Andreas Grib Fibiger:X",
        "Kirsten Dunst:(ACTOR)::Valdis Zatlers:X",
        "Kirsten Dunst:(ACTOR)::Gianfranco Zola:X",
        "Kirsten Dunst:(ACTOR)::Željko Joksimović:X",
        "Kirsten Dunst:(ACTOR)::Ish-bosheth:X",
        "Kirsten Dunst:(ACTOR)::Edward VII of the United Kingdom:X",
        "Kirsten Dunst:(ACTOR)::Daniel Jarque:X",
        "Georges Brassens:(SINGER)::Ali al-Masudi:X",
        "Georges Brassens:(SINGER)::Carlo Borromeo:X",
        "Georges Brassens:(SINGER)::Antoninus Pius:X",
        "Georges Brassens:(SINGER)::William IX, Duke of Aquitaine:X"
    ],
    "Analogical Answer": [
        "Historian",
        "Roman Catholic Cardinal",
        "Emperor of Rome",
        "Poet and troubadour",
        "Pope Martin I was a clergyman",
        "Poet",
        "Physiologist",
        "Valdis Zatlers is a physician",
        "Football manager",
        "Singer and songwriter",
        "King of Israel",
        "King of the United Kingdom",
        "Professional footballer",
        "Historian",
        "Roman Catholic Cardinal",
        "Emperor of Rome",
        "Poet and troubadour"
    ],
    "Technical Answer": [
        "WRITER",
        "RELIGIOUS FIGURE",
        "POLITICIAN",
        "NOBLEMAN",
        "RELIGIOUS FIGURE",
        "SOCIAL ACTIVIST",
        "PHYSICIAN",
        "POLITICIAN",
        "SOCCER PLAYER",
        "MUSICIAN",
        "POLITICIAN",
        "NOBLEMAN",
        "SOCCER PLAYER",
        "WRITER",
        "RELIGIOUS FIGURE",
        "POLITICIAN",
        "NOBLEMAN"
    ],
    "Response": [
        "HISTORIAN",
        "Saint",
        "Roman Emperor",
        "Troubadour",
        "POPE",
        "POET",
        "NOBEL PRIZE LAUREATE",
        "POLITICIAN",
        "FOOTBALLER",
        "MUSICIAN",
        "King",
        "MONARCH",
        "FOOTBALLER",
        "HISTORIAN",
        "Saint",
        "Roman emperor",
        "POET"
    ],
    "Status": [
        "Analogically Correct",
        "Fully Wrong",
        "Fully Wrong",
        "Analogically Correct",
        "Analogically Correct",
        "Analogically Correct",
        "Fully Wrong",
        "Technically Correct",
        "Fully Wrong",
        "Technically Correct",
        "Analogically Correct",
        "Fully Wrong",
        "Fully Wrong",
        "Analogically Correct",
        "Fully Wrong",
        "Fully Wrong",
        "Fully Wrong"
    ]
}

# Converting to DataFrame
df_part1 = pd.DataFrame(data_part1)
df_part1
# Out:
#                                                Prompt  \
# 0              Kirsten Dunst:(ACTOR)::Ali al-Masudi:X
# 1             Kirsten Dunst:(ACTOR)::Carlo Borromeo:X
# 2             Kirsten Dunst:(ACTOR)::Antoninus Pius:X
# 3   Kirsten Dunst:(ACTOR)::William IX, Duke of Aqu...
# 4              Kirsten Dunst:(ACTOR)::Pope Martin I:X
# 5              Kirsten Dunst:(ACTOR)::Yannis Ritsos:X
# 6   Kirsten Dunst:(ACTOR)::Johannes Andreas Grib F...
# 7             Kirsten Dunst:(ACTOR)::Valdis Zatlers:X
# 8            Kirsten Dunst:(ACTOR)::Gianfranco Zola:X
# 9          Kirsten Dunst:(ACTOR)::Željko Joksimović:X
# 10               Kirsten Dunst:(ACTOR)::Ish-bosheth:X
# 11  Kirsten Dunst:(ACTOR)::Edward VII of the Unite...
# 12             Kirsten Dunst:(ACTOR)::Daniel Jarque:X
# 13         Georges Brassens:(SINGER)::Ali al-Masudi:X
# 14        Georges Brassens:(SINGER)::Carlo Borromeo:X
# 15        Georges Brassens:(SINGER)::Antoninus Pius:X
# 16  Georges Brassens:(SINGER)::William IX, Duke of...
#
#                 Analogical Answer  Technical Answer              Response  \
# 0                       Historian            WRITER             HISTORIAN
# 1         Roman Catholic Cardinal  RELIGIOUS FIGURE                 Saint
# 2                 Emperor of Rome        POLITICIAN         Roman Emperor
# 3             Poet and troubadour          NOBLEMAN            Troubadour
# 4   Pope Martin I was a clergyman  RELIGIOUS FIGURE                  POPE
# 5                            Poet   SOCIAL ACTIVIST                  POET
# 6                    Physiologist         PHYSICIAN  NOBEL PRIZE LAUREATE
# 7   Valdis Zatlers is a physician        POLITICIAN            POLITICIAN
# 8                Football manager     SOCCER PLAYER            FOOTBALLER
# 9           Singer and songwriter          MUSICIAN              MUSICIAN
# 10                 King of Israel        POLITICIAN                  King
# 11     King of the United Kingdom          NOBLEMAN               MONARCH
# 12        Professional footballer     SOCCER PLAYER            FOOTBALLER
# 13                      Historian            WRITER             HISTORIAN
# 14        Roman Catholic Cardinal  RELIGIOUS FIGURE                 Saint
# 15                Emperor of Rome        POLITICIAN         Roman emperor
# 16            Poet and troubadour          NOBLEMAN                  POET
#
#                   Status
# 0   Analogically Correct
# 1            Fully Wrong
# 2            Fully Wrong
# 3   Analogically Correct
# 4   Analogically Correct
# 5   Analogically Correct
# 6            Fully Wrong
# 7    Technically Correct
# 8            Fully Wrong
# 9    Technically Correct
# 10  Analogically Correct
# 11           Fully Wrong
# 12           Fully Wrong
# 13  Analogically Correct
# 14           Fully Wrong
# 15           Fully Wrong
# 16           Fully Wrong

# %%
# Creating a pandas DataFrame with the given prompts and their evaluations (Part 2)
data_part2 = {
    "Prompt": [
        "Georges Brassens:(SINGER)::Pope Martin I:X",
        "Georges Brassens:(SINGER)::Yannis Ritsos:X",
        "Georges Brassens:(SINGER)::Johannes Andreas Grib Fibiger:X",
        "Georges Brassens:(SINGER)::Valdis Zatlers:X",
        "Georges Brassens:(SINGER)::Gianfranco Zola:X",
        "Georges Brassens:(SINGER)::Željko Joksimović:X",
        "Georges Brassens:(SINGER)::Ish-bosheth:X",
        "Georges Brassens:(SINGER)::Edward VII of the United Kingdom:X",
        "Georges Brassens:(SINGER)::Daniel Jarque:X",
        "Emil Cioran:(PHILOSOPHER)::Ali al-Masudi:X",
        "Emil Cioran:(PHILOSOPHER)::Carlo Borromeo:X",
        "Emil Cioran:(PHILOSOPHER)::Antoninus Pius:X",
        "Emil Cioran:(PHILOSOPHER)::William IX, Duke of Aquitaine:X",
        "Emil Cioran:(PHILOSOPHER)::Pope Martin I:X",
        "Emil Cioran:(PHILOSOPHER)::Yannis Ritsos:X",
        "Emil Cioran:(PHILOSOPHER)::Johannes Andreas Grib Fibiger:X",
        "Emil Cioran:(PHILOSOPHER)::Valdis Zatlers:X"
    ],
    "Analogical Answer": [
        "Pope Martin I was a clergyman",
        "Poet",
        "Physiologist",
        "Valdis Zatlers is a physician",
        "Football manager",
        "Singer and songwriter",
        "King of Israel",
        "King of the United Kingdom",
        "Professional footballer",
        "Historian",
        "Roman Catholic Cardinal",
        "Emperor of Rome",
        "Poet and troubadour",
        "Pope Martin I was a clergyman",
        "Poet",
        "Physiologist",
        "Valdis Zatlers is a physician"
    ],
    "Technical Answer": [
        "RELIGIOUS FIGURE",
        "SOCIAL ACTIVIST",
        "PHYSICIAN",
        "POLITICIAN",
        "SOCCER PLAYER",
        "MUSICIAN",
        "POLITICIAN",
        "NOBLEMAN",
        "SOCCER PLAYER",
        "WRITER",
        "RELIGIOUS FIGURE",
        "POLITICIAN",
        "NOBLEMAN",
        "RELIGIOUS FIGURE",
        "SOCIAL ACTIVIST",
        "PHYSICIAN",
        "POLITICIAN"
    ],
    "Response": [
        "Pope Martin I is a religious figure.",
        "POET",
        "Nobel laureate",
        "President",
        "SOCCER PLAYER",
        "MUSICIAN",
        "Saul (SON OF KING SAUL)",
        "KING",
        "Daniel Jarque:(FOOTBALLER)",
        "Historian.",
        "Saint",
        "Roman emperor",
        "POET",
        "Pope Martin I:(SAINT)",
        "POET",
        "Physiologist",
        "President"
    ],
    "Status": [
        "Technically Correct",
        "Analogically Correct",
        "Fully Wrong",
        "Fully Wrong",
        "Technically Correct",
        "Technically Correct",
        "Fully Wrong",
        "Analogically Correct",
        "Fully Wrong",
        "Analogically Correct",
        "Fully Wrong",
        "Fully Wrong",
        "Analogically Correct",
        "Fully Wrong",
        "Analogically Correct",
        "Analogically Correct",
        "Fully Wrong"
    ]
}

# Converting to DataFrame
df_part2 = pd.DataFrame(data_part2)
df_part2
# Out:
#                                                Prompt  \
# 0          Georges Brassens:(SINGER)::Pope Martin I:X
# 1          Georges Brassens:(SINGER)::Yannis Ritsos:X
# 2   Georges Brassens:(SINGER)::Johannes Andreas Gr...
# 3         Georges Brassens:(SINGER)::Valdis Zatlers:X
# 4        Georges Brassens:(SINGER)::Gianfranco Zola:X
# 5      Georges Brassens:(SINGER)::Željko Joksimović:X
# 6            Georges Brassens:(SINGER)::Ish-bosheth:X
# 7   Georges Brassens:(SINGER)::Edward VII of the U...
# 8          Georges Brassens:(SINGER)::Daniel Jarque:X
# 9          Emil Cioran:(PHILOSOPHER)::Ali al-Masudi:X
# 10        Emil Cioran:(PHILOSOPHER)::Carlo Borromeo:X
# 11        Emil Cioran:(PHILOSOPHER)::Antoninus Pius:X
# 12  Emil Cioran:(PHILOSOPHER)::William IX, Duke of...
# 13         Emil Cioran:(PHILOSOPHER)::Pope Martin I:X
# 14         Emil Cioran:(PHILOSOPHER)::Yannis Ritsos:X
# 15  Emil Cioran:(PHILOSOPHER)::Johannes Andreas Gr...
# 16        Emil Cioran:(PHILOSOPHER)::Valdis Zatlers:X
#
#                 Analogical Answer  Technical Answer  \
# 0   Pope Martin I was a clergyman  RELIGIOUS FIGURE
# 1                            Poet   SOCIAL ACTIVIST
# 2                    Physiologist         PHYSICIAN
# 3   Valdis Zatlers is a physician        POLITICIAN
# 4                Football manager     SOCCER PLAYER
# 5           Singer and songwriter          MUSICIAN
# 6                  King of Israel        POLITICIAN
# 7      King of the United Kingdom          NOBLEMAN
# 8         Professional footballer     SOCCER PLAYER
# 9                       Historian            WRITER
# 10        Roman Catholic Cardinal  RELIGIOUS FIGURE
# 11                Emperor of Rome        POLITICIAN
# 12            Poet and troubadour          NOBLEMAN
# 13  Pope Martin I was a clergyman  RELIGIOUS FIGURE
# 14                           Poet   SOCIAL ACTIVIST
# 15                   Physiologist         PHYSICIAN
# 16  Valdis Zatlers is a physician        POLITICIAN
#
#                                 Response                Status
# 0   Pope Martin I is a religious figure.   Technically Correct
# 1                                   POET  Analogically Correct
# 2                         Nobel laureate           Fully Wrong
# 3                              President           Fully Wrong
# 4                          SOCCER PLAYER   Technically Correct
# 5                               MUSICIAN   Technically Correct
# 6                Saul (SON OF KING SAUL)           Fully Wrong
# 7                                   KING  Analogically Correct
# 8             Daniel Jarque:(FOOTBALLER)           Fully Wrong
# 9                             Historian.  Analogically Correct
# 10                                 Saint           Fully Wrong
# 11                         Roman emperor           Fully Wrong
# 12                                  POET  Analogically Correct
# 13                 Pope Martin I:(SAINT)           Fully Wrong
# 14                                  POET  Analogically Correct
# 15                          Physiologist  Analogically Correct
# 16                             President           Fully Wrong

# %%
df_merged = pd.concat([df_part1, df_part2], ignore_index=True)
# result_df = pd.DataFrame(columns=['Prompt', 'Analogical Answer', 'Technical Answer', 'Response', 'Status'], data=result)
df_merged.to_csv('../results/result: person-occupation-adversial.csv')
df_merged
# Out:
#                                                Prompt  \
# 0              Kirsten Dunst:(ACTOR)::Ali al-Masudi:X
# 1             Kirsten Dunst:(ACTOR)::Carlo Borromeo:X
# 2             Kirsten Dunst:(ACTOR)::Antoninus Pius:X
# 3   Kirsten Dunst:(ACTOR)::William IX, Duke of Aqu...
# 4              Kirsten Dunst:(ACTOR)::Pope Martin I:X
# 5              Kirsten Dunst:(ACTOR)::Yannis Ritsos:X
# 6   Kirsten Dunst:(ACTOR)::Johannes Andreas Grib F...
# 7             Kirsten Dunst:(ACTOR)::Valdis Zatlers:X
# 8            Kirsten Dunst:(ACTOR)::Gianfranco Zola:X
# 9          Kirsten Dunst:(ACTOR)::Željko Joksimović:X
# 10               Kirsten Dunst:(ACTOR)::Ish-bosheth:X
# 11  Kirsten Dunst:(ACTOR)::Edward VII of the Unite...
# 12             Kirsten Dunst:(ACTOR)::Daniel Jarque:X
# 13         Georges Brassens:(SINGER)::Ali al-Masudi:X
# 14        Georges Brassens:(SINGER)::Carlo Borromeo:X
# 15        Georges Brassens:(SINGER)::Antoninus Pius:X
# 16  Georges Brassens:(SINGER)::William IX, Duke of...
# 17         Georges Brassens:(SINGER)::Pope Martin I:X
# 18         Georges Brassens:(SINGER)::Yannis Ritsos:X
# 19  Georges Brassens:(SINGER)::Johannes Andreas Gr...
# 20        Georges Brassens:(SINGER)::Valdis Zatlers:X
# 21       Georges Brassens:(SINGER)::Gianfranco Zola:X
# 22     Georges Brassens:(SINGER)::Željko Joksimović:X
# 23           Georges Brassens:(SINGER)::Ish-bosheth:X
# 24  Georges Brassens:(SINGER)::Edward VII of the U...
# 25         Georges Brassens:(SINGER)::Daniel Jarque:X
# 26         Emil Cioran:(PHILOSOPHER)::Ali al-Masudi:X
# 27        Emil Cioran:(PHILOSOPHER)::Carlo Borromeo:X
# 28        Emil Cioran:(PHILOSOPHER)::Antoninus Pius:X
# 29  Emil Cioran:(PHILOSOPHER)::William IX, Duke of...
# 30         Emil Cioran:(PHILOSOPHER)::Pope Martin I:X
# 31         Emil Cioran:(PHILOSOPHER)::Yannis Ritsos:X
# 32  Emil Cioran:(PHILOSOPHER)::Johannes Andreas Gr...
# 33        Emil Cioran:(PHILOSOPHER)::Valdis Zatlers:X
#
#                 Analogical Answer  Technical Answer  \
# 0                       Historian            WRITER
# 1         Roman Catholic Cardinal  RELIGIOUS FIGURE
# 2                 Emperor of Rome        POLITICIAN
# 3             Poet and troubadour          NOBLEMAN
# 4   Pope Martin I was a clergyman  RELIGIOUS FIGURE
# 5                            Poet   SOCIAL ACTIVIST
# 6                    Physiologist         PHYSICIAN
# 7   Valdis Zatlers is a physician        POLITICIAN
# 8                Football manager     SOCCER PLAYER
# 9           Singer and songwriter          MUSICIAN
# 10                 King of Israel        POLITICIAN
# 11     King of the United Kingdom          NOBLEMAN
# 12        Professional footballer     SOCCER PLAYER
# 13                      Historian            WRITER
# 14        Roman Catholic Cardinal  RELIGIOUS FIGURE
# 15                Emperor of Rome        POLITICIAN
# 16            Poet and troubadour          NOBLEMAN
# 17  Pope Martin I was a clergyman  RELIGIOUS FIGURE
# 18                           Poet   SOCIAL ACTIVIST
# 19                   Physiologist         PHYSICIAN
# 20  Valdis Zatlers is a physician        POLITICIAN
# 21               Football manager     SOCCER PLAYER
# 22          Singer and songwriter          MUSICIAN
# 23                 King of Israel        POLITICIAN
# 24     King of the United Kingdom          NOBLEMAN
# 25        Professional footballer     SOCCER PLAYER
# 26                      Historian            WRITER
# 27        Roman Catholic Cardinal  RELIGIOUS FIGURE
# 28                Emperor of Rome        POLITICIAN
# 29            Poet and troubadour          NOBLEMAN
# 30  Pope Martin I was a clergyman  RELIGIOUS FIGURE
# 31                           Poet   SOCIAL ACTIVIST
# 32                   Physiologist         PHYSICIAN
# 33  Valdis Zatlers is a physician        POLITICIAN
#
#                                 Response                Status
# 0                              HISTORIAN  Analogically Correct
# 1                                  Saint           Fully Wrong
# 2                          Roman Emperor           Fully Wrong
# 3                             Troubadour  Analogically Correct
# 4                                   POPE  Analogically Correct
# 5                                   POET  Analogically Correct
# 6                   NOBEL PRIZE LAUREATE           Fully Wrong
# 7                             POLITICIAN   Technically Correct
# 8                             FOOTBALLER           Fully Wrong
# 9                               MUSICIAN   Technically Correct
# 10                                  King  Analogically Correct
# 11                               MONARCH           Fully Wrong
# 12                            FOOTBALLER           Fully Wrong
# 13                             HISTORIAN  Analogically Correct
# 14                                 Saint           Fully Wrong
# 15                         Roman emperor           Fully Wrong
# 16                                  POET           Fully Wrong
# 17  Pope Martin I is a religious figure.   Technically Correct
# 18                                  POET  Analogically Correct
# 19                        Nobel laureate           Fully Wrong
# 20                             President           Fully Wrong
# 21                         SOCCER PLAYER   Technically Correct
# 22                              MUSICIAN   Technically Correct
# 23               Saul (SON OF KING SAUL)           Fully Wrong
# 24                                  KING  Analogically Correct
# 25            Daniel Jarque:(FOOTBALLER)           Fully Wrong
# 26                            Historian.  Analogically Correct
# 27                                 Saint           Fully Wrong
# 28                         Roman emperor           Fully Wrong
# 29                                  POET  Analogically Correct
# 30                 Pope Martin I:(SAINT)           Fully Wrong
# 31                                  POET  Analogically Correct
# 32                          Physiologist  Analogically Correct
# 33                             President           Fully Wrong
