# %%
import pandas as pd
import numpy as np
from time import sleep
from openai import OpenAI
from private_data import API_KEY
import re

# %%
# Main query function
client = OpenAI(api_key=API_KEY)
def ask_query(query):
    my_query = [ {"role": "system", "content": "Give direct answer without any explanation."},
        {"role": "user", "content": query} ] 
    completion = client.chat.completions.create(
        model="gpt-3.5-turbo", messages=my_query
    )
    return str(completion.choices[0].message.content)

# %%
# Loading Dataset 
person_death_df = pd.read_csv('../data/celebrity_deaths_4.csv', encoding = 'MacRoman')
person_death_df = person_death_df[['name', 'death_month' , 'death_year']]
person_death_df['death_date'] = person_death_df['death_month'].astype(str) + ' ' + person_death_df['death_year'].astype(str)
# # Shuffle and resize the data
person_death_df = person_death_df.sample(frac=1).reset_index(drop=True).head(100)

person_death_df.head(10)
# Out:
#                         name death_month  death_year      death_date
# 0                Arnold Fine   September        2014  September 2014
# 1             Beverly Fawell        June        2013       June 2013
# 2            Raymond Daniels     January        2008    January 2008
# 3               Dickie Jeeps     October        2016    October 2016
# 4              Collin Wilcox     October        2009    October 2009
# 5               Larry Turner    November        2009   November 2009
# 6           Motoichi Kumagai    November        2010   November 2010
# 7                  Bob Welch        June        2012       June 2012
# 8  JoaquÃ_n PiÃ±a Batllevell        July        2013       July 2013
# 9               Mimi Darwish    December        2011   December 2011

# %%
# Preprocessing 

def normalize(entity):
    entity = entity.lower()
    
    return entity
    

def are_equivalent(response, answer):
    response = normalize(response)
    answer = normalize(answer)

    if answer in response:
        return True
    if response in answer:
        return True
    return False

def contains_date(response):
    x = response.replace('-', ' ')
    x = x.replace('.', ' ')
    
    for w in x.split():
        if len(w)==4 and w.isnumeric():
            return True
    return False
    
def does_gpt_know(person, deathdate):
    # check if birthdate is nan
    if pd.isnull(deathdate) or pd.isnull(person):
        return 0
    
    query = f"what is the death date(Month YYYY) of {person}?"
    response = ask_query(query)
    print(f"Person: {person} \t|\t Death Date: {deathdate} \t|\t Response: {response}")
    
    if are_equivalent(response, deathdate):
        return 1
    elif contains_date(response):
        return 2
    
    return 0
    



def preprocess(df):
    correct_answers = []
    wrong_answers = []
    for index, row in df.iterrows():
        x = does_gpt_know(row['name'], row['death_date'])
        if x==1:
            correct_answers.append(row)
        elif x==2:
            ###############################################
            # add new column: reply
            wrong_answers.append(row)
        print(len(correct_answers), len(wrong_answers))
        if len(correct_answers) >= 10 and len(wrong_answers)>=10:
            break
    correct_df = pd.DataFrame(correct_answers)
    wrong_df = pd.DataFrame(wrong_answers)
    return correct_df, wrong_df

# %%
known_df = preprocess(person_death_df)
known_df
# Out:
# Person: Arnold Fine 	|	 Death Date: September 2014 	|	 Response: July 2012
# 0 1
# Person: Beverly Fawell 	|	 Death Date: June 2013 	|	 Response: August 2012
# 0 2
# Person: Raymond Daniels 	|	 Death Date: January 2008 	|	 Response: Raymond Daniels passed away in June 2022.
# 0 3
# Person: Dickie Jeeps 	|	 Death Date: October 2016 	|	 Response: October 2016
# 1 3
# Person: Collin Wilcox 	|	 Death Date: October 2009 	|	 Response: October 2009.
# 2 3
# Person: Larry Turner 	|	 Death Date: November 2009 	|	 Response: December 2020
# 2 4
# Person: Motoichi Kumagai 	|	 Death Date: November 2010 	|	 Response: February 2020
# 2 5
# Person: Bob Welch 	|	 Death Date: June 2012 	|	 Response: June 2012.
# 3 5
# Person: JoaquÃ_n PiÃ±a Batllevell 	|	 Death Date: July 2013 	|	 Response: October 2010
# 3 6
# Person: Mimi Darwish 	|	 Death Date: December 2011 	|	 Response: June 2021.
# 3 7
# Person: Vladimir Kesarev 	|	 Death Date: January 2015 	|	 Response: April 1966
# 3 8
# Person: Patrick Francis Sheehan 	|	 Death Date: November 2012 	|	 Response: March 2024
# 3 9
# Person: George Ardisson 	|	 Death Date: December 2014 	|	 Response: August 2014.
# 3 10
# Person: Marian Przykucki 	|	 Death Date: October 2009 	|	 Response: December 2019
# 3 11
# Person: Joe Rogers 	|	 Death Date: October 2013 	|	 Response: June 2021
# 3 12
# Person: William Henry Bullock 	|	 Death Date: April 2011 	|	 Response: November 2019.
# 3 13
# Person: JÃ_zef Pazdur 	|	 Death Date: May 2015 	|	 Response: December 2021
# 3 14
# Person: Mario Francesco Pompedda 	|	 Death Date: October 2006 	|	 Response: September 2006
# 3 15
# Person: Harvansh Singh 	|	 Death Date: May 2013 	|	 Response: April 2007
# 3 16
# Person: Joe Ginsberg 	|	 Death Date: November 2012 	|	 Response: December 2021
# 3 17
# Person: Tsunetoshi Tanaka 	|	 Death Date: January 2014 	|	 Response: November 1972.
# 3 18
# Person: Molly Glynn 	|	 Death Date: September 2014 	|	 Response: September 2014
# 4 18
# Person: Vilgot SjÃ¶man 	|	 Death Date: April 2006 	|	 Response: April 2006
# 5 18
# Person: Dennis Byrd 	|	 Death Date: October 2016 	|	 Response: October 2016
# 6 18
# Person: Francisco Ovidio Vera Intriago 	|	 Death Date: April 2014 	|	 Response: February 2020
# 6 19
# Person: Gordon Hessler 	|	 Death Date: January 2014 	|	 Response: May 2014
# 6 20
# Person: Guillermo Luksic Craig 	|	 Death Date: March 2013 	|	 Response: March 2013
# 7 20
# Person: Sossen Krohg 	|	 Death Date: February 2016 	|	 Response: July 1976
# 7 21
# Person: Chris Dedrick 	|	 Death Date: August 2010 	|	 Response: December 2010.
# 7 22
# Person: Salvador BernÃ¡rdez 	|	 Death Date: July 2011 	|	 Response: February 1991.
# 7 23
# Person: Piet Fransen 	|	 Death Date: August 2015 	|	 Response: January 2020.
# 7 24
# Person: Bryan O'Linn 	|	 Death Date: July 2015 	|	 Response: October 1942
# 7 25
# Person: Michel Hugo 	|	 Death Date: October 2010 	|	 Response: May 1985
# 7 26
# Person: Charlie L. Russell 	|	 Death Date: June 2013 	|	 Response: January 1926
# 7 27
# Person: Kenji Kosaka 	|	 Death Date: October 2016 	|	 Response: November 2020
# 7 28
# Person: Sir John Martin 	|	 Death Date: May 2011 	|	 Response: Sir John Martin died in October 2017.
# 7 29
# Person: Colin Campbell 	|	 Death Date: January 2012 	|	 Response: June 2021
# 7 30
# Person: Pierre Claude Nolin 	|	 Death Date: April 2015 	|	 Response: December 2015
# 7 31
# Person: Reginald Turnill 	|	 Death Date: February 2013 	|	 Response: February 2013
# 8 31
# Person: Clay Felker 	|	 Death Date: July 2008 	|	 Response: July 2008
# 9 31
# Person: Bill Barrett 	|	 Death Date: September 2016 	|	 Response: October 2016
# 9 32
# Person: Bowie Kuhn 	|	 Death Date: March 2007 	|	 Response: March 2007.
# 10 32
# (                      name death_month  death_year      death_date
#  3             Dickie Jeeps     October        2016    October 2016
#  4            Collin Wilcox     October        2009    October 2009
#  7                Bob Welch        June        2012       June 2012
#  21             Molly Glynn   September        2014  September 2014
#  22          Vilgot SjÃ¶man       April        2006      April 2006
#  23             Dennis Byrd     October        2016    October 2016
#  26  Guillermo Luksic Craig       March        2013      March 2013
#  38        Reginald Turnill    February        2013   February 2013
#  39             Clay Felker        July        2008       July 2008
#  41              Bowie Kuhn       March        2007      March 2007,
#                                name death_month  death_year      death_date
#  0                      Arnold Fine   September        2014  September 2014
#  1                   Beverly Fawell        June        2013       June 2013
#  2                  Raymond Daniels     January        2008    January 2008
#  5                     Larry Turner    November        2009   November 2009
#  6                 Motoichi Kumagai    November        2010   November 2010
#  8        JoaquÃ_n PiÃ±a Batllevell        July        2013       July 2013
#  9                     Mimi Darwish    December        2011   December 2011
#  10                Vladimir Kesarev     January        2015    January 2015
#  11         Patrick Francis Sheehan    November        2012   November 2012
#  12                 George Ardisson    December        2014   December 2014
#  13                Marian Przykucki     October        2009    October 2009
#  14                      Joe Rogers     October        2013    October 2013
#  15           William Henry Bullock       April        2011      April 2011
#  16                   JÃ_zef Pazdur         May        2015        May 2015
#  17        Mario Francesco Pompedda     October        2006    October 2006
#  18                  Harvansh Singh         May        2013        May 2013
#  19                    Joe Ginsberg    November        2012   November 2012
#  20               Tsunetoshi Tanaka     January        2014    January 2014
#  24  Francisco Ovidio Vera Intriago       April        2014      April 2014
#  25                  Gordon Hessler     January        2014    January 2014
#  27                    Sossen Krohg    February        2016   February 2016
#  28                   Chris Dedrick      August        2010     August 2010
#  29             Salvador BernÃ¡rdez        July        2011       July 2011
#  30                    Piet Fransen      August        2015     August 2015
#  31                    Bryan O'Linn        July        2015       July 2015
#  32                     Michel Hugo     October        2010    October 2010
#  33              Charlie L. Russell        June        2013       June 2013
#  34                    Kenji Kosaka     October        2016    October 2016
#  35                 Sir John Martin         May        2011        May 2011
#  36                  Colin Campbell     January        2012    January 2012
#  37             Pierre Claude Nolin       April        2015      April 2015
#  40                    Bill Barrett   September        2016  September 2016)

# %%
correct_df, b = known_df
correct_df = correct_df.sample(frac=1).reset_index(drop=True).head(20)
correct_df.rename(columns={'name': 'Entity', 'death_date': 'Target'}, inplace=True)
correct_df
# Out:
#                    Entity death_month  death_year          Target
# 0              Bowie Kuhn       March        2007      March 2007
# 1        Reginald Turnill    February        2013   February 2013
# 2             Molly Glynn   September        2014  September 2014
# 3          Vilgot SjÃ¶man       April        2006      April 2006
# 4  Guillermo Luksic Craig       March        2013      March 2013
# 5               Bob Welch        June        2012       June 2012
# 6           Collin Wilcox     October        2009    October 2009
# 7             Dennis Byrd     October        2016    October 2016
# 8            Dickie Jeeps     October        2016    October 2016
# 9             Clay Felker        July        2008       July 2008

# %%
# Data
data = {
    "Person": ["Arnold Fine", "Beverly Fawell", "Raymond Daniels", "Collin Wilcox",
               "Larry Turner", "Motoichi Kumagai", "Joaquín Piña Batllevell", "Mimi Darwish",
               "Vladimir Kesarev", "Patrick Francis Sheehan", "George Ardisson",
               "Marian Przykucki", "Joe Rogers"],
    "Death Date": ["September 2014", "June 2013", "January 2008", "October 2009",
                   "November 2009", "November 2010", "July 2013", "December 2011",
                   "January 2015", "November 2012", "December 2014", "October 2009",
                   "October 2013"],
    "Response": ["July 2012", "August 2012", "June 2022",
                 "October 2009", "December 2020", "February 2020", "October 2010",
                 "June 2021", "April 1966", "March 2024", "August 2014", "December 2019",
                 "June 2021"]
}

# Create the updated DataFrame
wrong_df = pd.DataFrame(data)
wrong_df.rename(columns={'Person': 'Entity', 'Death Date': 'Correct', 'Response': 'Target'}, inplace=True)

wrong_df
# Out:
#                      Entity         Correct         Target
# 0               Arnold Fine  September 2014      July 2012
# 1            Beverly Fawell       June 2013    August 2012
# 2           Raymond Daniels    January 2008      June 2022
# 3             Collin Wilcox    October 2009   October 2009
# 4              Larry Turner   November 2009  December 2020
# 5          Motoichi Kumagai   November 2010  February 2020
# 6   Joaquín Piña Batllevell       July 2013   October 2010
# 7              Mimi Darwish   December 2011      June 2021
# 8          Vladimir Kesarev    January 2015     April 1966
# 9   Patrick Francis Sheehan   November 2012     March 2024
# 10          George Ardisson   December 2014    August 2014
# 11         Marian Przykucki    October 2009  December 2019
# 12               Joe Rogers    October 2013      June 2021

# %%
def date_analogy_testing(df1, df2, equiv_func):
    result = []
    n, m = len(df1), len(df2)
    
    for i in range(20):
        entity_1 = df1.iloc[i%n]['Entity']
        target_1 = df1.iloc[i%n]['Target']
        
        j = i%m 
        entity_2 = df2.iloc[j]['Entity']
        target_2 = df2.iloc[j]['Target']
        correct_ans = df2.iloc[j]['Correct']
        
        prompt = f"{entity_1}:({target_1})::{entity_2}:X; what is X?"
        
        response = ask_query(prompt)
        
        status = "Fully Wrong"
        if equiv_func(response, target_2):
            status = "Analogically Correct"
        elif equiv_func(response, correct_ans):
            status = "Technically Correct"
        
        result.append({'Prompt': prompt, 'Analogical Answer': target_2, 'Technical Answer': correct_ans , 'GPT-reply': response, 'Status': status})
        print(f"Prompt: {prompt} \t|\t Analogical Answer: {target_2}, Technical Answer: {correct_ans} \t|\t Response: {response} \t|\t Status: {status}")
    
    return result

# %%
result = date_analogy_testing(correct_df, wrong_df, are_equivalent)
# Out:
# Prompt: Bowie Kuhn:(March 2007)::Arnold Fine:X; what is X? 	|	 Analogical Answer: July 2012, Technical Answer: September 2014 	|	 Response: April 2008 	|	 Status: Fully Wrong
# Prompt: Reginald Turnill:(February 2013)::Beverly Fawell:X; what is X? 	|	 Analogical Answer: August 2012, Technical Answer: June 2013 	|	 Response: December 2012 	|	 Status: Fully Wrong
# Prompt: Molly Glynn:(September 2014)::Raymond Daniels:X; what is X? 	|	 Analogical Answer: June 2022, Technical Answer: January 2008 	|	 Response: September 2014 	|	 Status: Fully Wrong
# Prompt: Vilgot SjÃ¶man:(April 2006)::Collin Wilcox:X; what is X? 	|	 Analogical Answer: October 2009, Technical Answer: October 2009 	|	 Response: To Kill a Mockingbird 	|	 Status: Fully Wrong
# Prompt: Guillermo Luksic Craig:(March 2013)::Larry Turner:X; what is X? 	|	 Analogical Answer: December 2020, Technical Answer: November 2009 	|	 Response: Larry Turner died. 	|	 Status: Fully Wrong
# Prompt: Bob Welch:(June 2012)::Motoichi Kumagai:X; what is X? 	|	 Analogical Answer: February 2020, Technical Answer: November 2010 	|	 Response: May 2021 	|	 Status: Fully Wrong
# Prompt: Collin Wilcox:(October 2009)::Joaquín Piña Batllevell:X; what is X? 	|	 Analogical Answer: October 2010, Technical Answer: July 2013 	|	 Response: January 1968 	|	 Status: Fully Wrong
# Prompt: Dennis Byrd:(October 2016)::Mimi Darwish:X; what is X? 	|	 Analogical Answer: June 2021, Technical Answer: December 2011 	|	 Response: December 2017 	|	 Status: Fully Wrong
# Prompt: Dickie Jeeps:(October 2016)::Vladimir Kesarev:X; what is X? 	|	 Analogical Answer: April 1966, Technical Answer: January 2015 	|	 Response: June 2021 	|	 Status: Fully Wrong
# Prompt: Clay Felker:(July 2008)::Patrick Francis Sheehan:X; what is X? 	|	 Analogical Answer: March 2024, Technical Answer: November 2012 	|	 Response: May 1988 	|	 Status: Fully Wrong
# Prompt: Bowie Kuhn:(March 2007)::George Ardisson:X; what is X? 	|	 Analogical Answer: August 2014, Technical Answer: December 2014 	|	 Response: September 2004 	|	 Status: Fully Wrong
# Prompt: Reginald Turnill:(February 2013)::Marian Przykucki:X; what is X? 	|	 Analogical Answer: December 2019, Technical Answer: October 2009 	|	 Response: Retired. 	|	 Status: Fully Wrong
# Prompt: Molly Glynn:(September 2014)::Joe Rogers:X; what is X? 	|	 Analogical Answer: June 2021, Technical Answer: October 2013 	|	 Response: August 2014 	|	 Status: Fully Wrong
# Prompt: Vilgot SjÃ¶man:(April 2006)::Arnold Fine:X; what is X? 	|	 Analogical Answer: July 2012, Technical Answer: September 2014 	|	 Response: January 1999 	|	 Status: Fully Wrong
# Prompt: Guillermo Luksic Craig:(March 2013)::Beverly Fawell:X; what is X? 	|	 Analogical Answer: August 2012, Technical Answer: June 2013 	|	 Response: September 2025 	|	 Status: Fully Wrong
# Prompt: Bob Welch:(June 2012)::Raymond Daniels:X; what is X? 	|	 Analogical Answer: June 2022, Technical Answer: January 2008 	|	 Response: October 2015 	|	 Status: Fully Wrong
# Prompt: Collin Wilcox:(October 2009)::Collin Wilcox:X; what is X? 	|	 Analogical Answer: October 2009, Technical Answer: October 2009 	|	 Response: X is April 1995. 	|	 Status: Fully Wrong
# Prompt: Dennis Byrd:(October 2016)::Larry Turner:X; what is X? 	|	 Analogical Answer: December 2020, Technical Answer: November 2009 	|	 Response: May 1982 	|	 Status: Fully Wrong
# Prompt: Dickie Jeeps:(October 2016)::Motoichi Kumagai:X; what is X? 	|	 Analogical Answer: February 2020, Technical Answer: November 2010 	|	 Response: June 2016 	|	 Status: Fully Wrong
# Prompt: Clay Felker:(July 2008)::Joaquín Piña Batllevell:X; what is X? 	|	 Analogical Answer: October 2010, Technical Answer: July 2013 	|	 Response:  José Martínez de Hoyos 	|	 Status: Fully Wrong

# %%
result_df = pd.DataFrame(columns=['Prompt', 'Analogical Answer', 'Technical Answer', 'GPT-reply', 'Status'], data=result)
result_df.to_csv('../results/result: person-deathdate-adversial.csv')
result_df
# Out:
#                                                Prompt Analogical Answer  \
# 0   Bowie Kuhn:(March 2007)::Arnold Fine:X; what i...         July 2012
# 1   Reginald Turnill:(February 2013)::Beverly Fawe...       August 2012
# 2   Molly Glynn:(September 2014)::Raymond Daniels:...         June 2022
# 3   Vilgot SjÃ¶man:(April 2006)::Collin Wilcox:X; ...      October 2009
# 4   Guillermo Luksic Craig:(March 2013)::Larry Tur...     December 2020
# 5   Bob Welch:(June 2012)::Motoichi Kumagai:X; wha...     February 2020
# 6   Collin Wilcox:(October 2009)::Joaquín Piña Bat...      October 2010
# 7   Dennis Byrd:(October 2016)::Mimi Darwish:X; wh...         June 2021
# 8   Dickie Jeeps:(October 2016)::Vladimir Kesarev:...        April 1966
# 9   Clay Felker:(July 2008)::Patrick Francis Sheeh...        March 2024
# 10  Bowie Kuhn:(March 2007)::George Ardisson:X; wh...       August 2014
# 11  Reginald Turnill:(February 2013)::Marian Przyk...     December 2019
# 12  Molly Glynn:(September 2014)::Joe Rogers:X; wh...         June 2021
# 13  Vilgot SjÃ¶man:(April 2006)::Arnold Fine:X; wh...         July 2012
# 14  Guillermo Luksic Craig:(March 2013)::Beverly F...       August 2012
# 15  Bob Welch:(June 2012)::Raymond Daniels:X; what...         June 2022
# 16  Collin Wilcox:(October 2009)::Collin Wilcox:X;...      October 2009
# 17  Dennis Byrd:(October 2016)::Larry Turner:X; wh...     December 2020
# 18  Dickie Jeeps:(October 2016)::Motoichi Kumagai:...     February 2020
# 19  Clay Felker:(July 2008)::Joaquín Piña Batlleve...      October 2010
#
#    Technical Answer                GPT-reply       Status
# 0    September 2014               April 2008  Fully Wrong
# 1         June 2013            December 2012  Fully Wrong
# 2      January 2008           September 2014  Fully Wrong
# 3      October 2009    To Kill a Mockingbird  Fully Wrong
# 4     November 2009       Larry Turner died.  Fully Wrong
# 5     November 2010                 May 2021  Fully Wrong
# 6         July 2013             January 1968  Fully Wrong
# 7     December 2011            December 2017  Fully Wrong
# 8      January 2015                June 2021  Fully Wrong
# 9     November 2012                 May 1988  Fully Wrong
# 10    December 2014           September 2004  Fully Wrong
# 11     October 2009                 Retired.  Fully Wrong
# 12     October 2013              August 2014  Fully Wrong
# 13   September 2014             January 1999  Fully Wrong
# 14        June 2013           September 2025  Fully Wrong
# 15     January 2008             October 2015  Fully Wrong
# 16     October 2009         X is April 1995.  Fully Wrong
# 17    November 2009                 May 1982  Fully Wrong
# 18    November 2010                June 2016  Fully Wrong
# 19        July 2013   José Martínez de Hoyos  Fully Wrong

# %%
# Define the data for the DataFrame
data = {
    "Prompt": [
        "Jorg Haider:(1950-01-26)::George Vecsey:X",
        "Jorg Haider:(1950-01-26)::Alicia Keys:X",
        "Jorg Haider:(1950-01-26)::William T Esrey:X",
        "Jorg Haider:(1950-01-26)::Arthur Laurents:X",
        "Jorg Haider:(1950-01-26)::Christoph von Dohnanyi:X",
        "Jorg Haider:(1950-01-26)::Donald L Evans:X",
        "Jorg Haider:(1950-01-26)::Kathleen Hall Jamieson:X",
        "Jorg Haider:(1950-01-26)::Elizabeth S Grubman:X",
        "Petr Korda:(1968-01-23)::George Vecsey:X",
        "Petr Korda:(1968-01-23)::Alicia Keys:X",
        "Petr Korda:(1968-01-23)::William T Esrey:X",
        "Petr Korda:(1968-01-23)::Arthur Laurents:X",
        "Petr Korda:(1968-01-23)::Christoph von Dohnanyi:X",
        "Petr Korda:(1968-01-23)::Donald L Evans:X",
        "Petr Korda:(1968-01-23)::Kathleen Hall Jamieson:X",
        "Petr Korda:(1968-01-23)::Elizabeth S Grubman:X",
        "Ariel Sharon:(1928-02-26)::George Vecsey:X",
        "Ariel Sharon:(1928-02-26)::Alicia Keys:X",
        "Ariel Sharon:(1928-02-26)::William T Esrey:X"
    ],
    "Analogical Answer": [
        "1939-07-04", "1980-01-25", "1940-01-01", "1918-07-14", "1929-09-08",
        "1946-07-26", "1946-01-01", "1971-01-30", "1939-07-04", "1980-01-25",
        "1940-01-01", "1918-07-14", "1929-09-08", "1946-07-26", "1946-01-01",
        "1971-01-30", "1939-07-04", "1980-01-25", "1940-01-01"
    ],
    "Technical Answer": [
        "1940-07-04", "1981-01-25", "1940-11-15", "1917-07-14", "1929-06-08",
        "1946-07-27", "1946-02-22", "1976-01-30", "1940-07-04", "1981-01-25",
        "1940-11-15", "1917-07-14", "1929-06-08", "1946-07-27", "1946-02-22",
        "1976-01-30", "1940-07-04", "1981-01-25", "1940-11-15"
    ],
    "Response": [
        "X is the birth date of George Vecsey, which is not provided in the question.",
        "1975-01-25", "Unknown", "Arthur Laurents:(1917-07-14)", "Unknown",
        "X is the date of birth of Donald L Evans.", "There is not enough information to determine what X represents.",
        "X is the birthdate of Elizabeth S Grubman, which is unknown based on the provided information.",
        "X is unknown or unspecified.", "1981-01-25", "Unknown.", "Unknown",
        "1949-09-08", "X is Donald L Evans's birth date.", "X is unknown or not given in the provided information.",
        "Unknown", "World War II or 1939-1945", "-\nnot applicable.", "Unknown or not given."
    ],
    "Status": [
        "Fully Wrong", "Fully Wrong", "Fully Wrong", "Technically Correct", "Fully Wrong",
        "Fully Wrong", "Fully Wrong", "Fully Wrong", "Fully Wrong", "Technically Correct",
        "Fully Wrong", "Fully Wrong", "Fully Wrong", "Fully Wrong", "Fully Wrong",
        "Fully Wrong", "Fully Wrong", "Fully Wrong", "Fully Wrong"
    ]
}

# Create the DataFrame
result_df = pd.DataFrame(data)
result_df
# Out:
#                                                Prompt Analogical Answer  \
# 0           Jorg Haider:(1950-01-26)::George Vecsey:X        1939-07-04
# 1             Jorg Haider:(1950-01-26)::Alicia Keys:X        1980-01-25
# 2         Jorg Haider:(1950-01-26)::William T Esrey:X        1940-01-01
# 3         Jorg Haider:(1950-01-26)::Arthur Laurents:X        1918-07-14
# 4   Jorg Haider:(1950-01-26)::Christoph von Dohnan...        1929-09-08
# 5          Jorg Haider:(1950-01-26)::Donald L Evans:X        1946-07-26
# 6   Jorg Haider:(1950-01-26)::Kathleen Hall Jamies...        1946-01-01
# 7     Jorg Haider:(1950-01-26)::Elizabeth S Grubman:X        1971-01-30
# 8            Petr Korda:(1968-01-23)::George Vecsey:X        1939-07-04
# 9              Petr Korda:(1968-01-23)::Alicia Keys:X        1980-01-25
# 10         Petr Korda:(1968-01-23)::William T Esrey:X        1940-01-01
# 11         Petr Korda:(1968-01-23)::Arthur Laurents:X        1918-07-14
# 12  Petr Korda:(1968-01-23)::Christoph von Dohnanyi:X        1929-09-08
# 13          Petr Korda:(1968-01-23)::Donald L Evans:X        1946-07-26
# 14  Petr Korda:(1968-01-23)::Kathleen Hall Jamieson:X        1946-01-01
# 15     Petr Korda:(1968-01-23)::Elizabeth S Grubman:X        1971-01-30
# 16         Ariel Sharon:(1928-02-26)::George Vecsey:X        1939-07-04
# 17           Ariel Sharon:(1928-02-26)::Alicia Keys:X        1980-01-25
# 18       Ariel Sharon:(1928-02-26)::William T Esrey:X        1940-01-01
#
#    Technical Answer                                           Response  \
# 0        1940-07-04  X is the birth date of George Vecsey, which is...
# 1        1981-01-25                                         1975-01-25
# 2        1940-11-15                                            Unknown
# 3        1917-07-14                       Arthur Laurents:(1917-07-14)
# 4        1929-06-08                                            Unknown
# 5        1946-07-27          X is the date of birth of Donald L Evans.
# 6        1946-02-22  There is not enough information to determine w...
# 7        1976-01-30  X is the birthdate of Elizabeth S Grubman, whi...
# 8        1940-07-04                       X is unknown or unspecified.
# 9        1981-01-25                                         1981-01-25
# 10       1940-11-15                                           Unknown.
# 11       1917-07-14                                            Unknown
# 12       1929-06-08                                         1949-09-08
# 13       1946-07-27                  X is Donald L Evans's birth date.
# 14       1946-02-22  X is unknown or not given in the provided info...
# 15       1976-01-30                                            Unknown
# 16       1940-07-04                          World War II or 1939-1945
# 17       1981-01-25                                 -\nnot applicable.
# 18       1940-11-15                              Unknown or not given.
#
#                  Status
# 0           Fully Wrong
# 1           Fully Wrong
# 2           Fully Wrong
# 3   Technically Correct
# 4           Fully Wrong
# 5           Fully Wrong
# 6           Fully Wrong
# 7           Fully Wrong
# 8           Fully Wrong
# 9   Technically Correct
# 10          Fully Wrong
# 11          Fully Wrong
# 12          Fully Wrong
# 13          Fully Wrong
# 14          Fully Wrong
# 15          Fully Wrong
# 16          Fully Wrong
# 17          Fully Wrong
# 18          Fully Wrong
